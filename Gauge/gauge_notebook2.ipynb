# %%
import numpy as np
import matplotlib.pyplot as plt

from detector import detector
from utils import tsplot

import warnings                                                              
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')

# %%
'''
Input: Faulty Needle 1
vibration detector takes input video file path and coordinates of the bounding box predicted by assumed Gauge Detector Model
'''

dObj = detector('input/needle.mp4', 0, cropX1=1, cropY1=100, cropX2=900, cropY2=1000)
white_pixel_count_needle_1 = dObj.pixel_count()
tsplot(white_pixel_count_needle_1, 0, "")

# %%
'''
Input: Faulty Needle 2
vibration detector takes input video file path and coordinates of the bounding box predicted by assumed Gauge Detector Model
'''
dObj = detector('input/needle2.mp4', 0, cropX1=1, cropY1=42, cropX2=1180, cropY2=1290)
white_pixel_count_needle_2 = dObj.pixel_count()
tsplot(white_pixel_count_needle_2, 0, "")

# %%
'''
Input: Stable Needle sample from public domain showing needle rising smoothly.
vibration detector takes input video file path and coordinates of the bounding box predicted by assumed Gauge Detector Model
'''

dObj = detector('input/stable-needle.mp4', 0, cropX1=180, cropY1=350, cropX2=350, cropY2=550)
white_pixel_count_stable_needle = dObj.pixel_count()
tsplot(white_pixel_count_stable_needle, 0, "")

# %%
'''
Input: Stable- Static Needle sample from public domain showing no movement at all.
vibration detector takes input video file path and coordinates of the bounding box predicted by assumed Gauge Detector Model
'''
dObj = detector('input/stable-needle2.mp4', 0, cropX1=340, cropY1=380, cropX2=530, cropY2=570)
white_pixel_count_stable_needle_2 = dObj.pixel_count()
tsplot(white_pixel_count_stable_needle_2, 0, "")
